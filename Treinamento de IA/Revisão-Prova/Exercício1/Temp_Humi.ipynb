# %%
import pandas as pd
import numpy as np
import seaborn as sns
import math
import matplotlib.pyplot as plt 
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
df = pd.read_csv('weatherHistory.csv', sep = ',')
df = df.dropna() 
X = df["Humidity"].values.reshape(-1,1)
Y = df["Temperature (C)"].values
# quanto maior for a humidade  maior é a temperatura

# %%
#Regressão linear
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size = 0.25, random_state=22)
regressor = LinearRegression()

regressor.fit(X_train,Y_train)
plt.scatter(X_train,Y_train,color='red')
plt.plot(X_train,regressor.predict(X_train),color='blue')
plt.title("Regressao Linear")
plt.xlabel("Humidity")
plt.ylabel("Temperature")
plt.show()
print("Metricas:")
print(f"R^2: {regressor.score(X_test,Y_test)}")
print(f"MSE: {mean_squared_error(Y_test,regressor.predict(X_test))}")
print(f"RMSE: {math.sqrt(mean_squared_error(Y_test,regressor.predict(X_test)))}")
# Out:
# Metricas:
# R^2: 0.3960546464962512
# MSE: 54.909894920302364
# RMSE: 7.410121113740474

# %%
X = df['Apparent Temperature (C)'].values.reshape(-1,1)
regressor = LinearRegression()

regressor.fit(X_train,Y_train)
plt.scatter(X_train,Y_train,color='red')
plt.plot(X_train,regressor.predict(X_train),color='blue')
plt.title("Regressao Linear")
plt.xlabel("Humidity")
plt.ylabel("Temperature")
plt.show()
print("Metricas para a temperatura aparente:")
print(f"R^2: {regressor.score(X_test,Y_test)}")
print(f"MSE: {mean_squared_error(Y_test,regressor.predict(X_test))}")
print(f"RMSE: {math.sqrt(mean_squared_error(Y_test,regressor.predict(X_test)))}")
# Out:
# Metricas para a temperatura aparente:
# R^2: 0.3960546464962512
# MSE: 54.909894920302364
# RMSE: 7.410121113740474
