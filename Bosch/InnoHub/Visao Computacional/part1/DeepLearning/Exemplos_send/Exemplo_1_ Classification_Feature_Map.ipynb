# %% [markdown]
#  -----------------------
#  **Problema** :
#
# Utilizaremos o dataset de Multi-Classes Iris.
#
#
# É um dos datasets mais utilizados em problemas de classificação multi-casse.
#
#
# A partir dos valores de comprimento e largura da sépala e pétalas de cada planta Iris, podemos classifica-la entre 3 variedades diferentes:
#
# * Setosa
# * Versicolore
# * Virginica

# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\bom5ca\documents\palestras_e_cursos\treinamento ai aplicada ico\.venv\lib\site-packages (1.2.4)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\bom5ca\documents\palestras_e_cursos\treinamento ai aplicada ico\.venv\lib\site-packages (from pandas) (1.18.5)
# Requirement already satisfied: pytz>=2017.3 in c:\users\bom5ca\documents\palestras_e_cursos\treinamento ai aplicada ico\.venv\lib\site-packages (from pandas) (2021.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\bom5ca\documents\palestras_e_cursos\treinamento ai aplicada ico\.venv\lib\site-packages (from pandas) (2.8.1)
# Requirement already satisfied: six>=1.5 in c:\users\bom5ca\documents\palestras_e_cursos\treinamento ai aplicada ico\.venv\lib\site-packages (from python-dateutil>=2.7.3->pandas) (1.15.0)

# %%
import sklearn
import numpy as np
import pandas as pd
from sklearn.svm import SVC
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from matplotlib.colors import ListedColormap

# Ignorar warnings
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Carregando os Dados

# %%
df = pd.read_csv("../dataset/iris.csv", header=0)
df.head()
# Out:
#    150    4  setosa  versicolor  virginica
# 0  5.1  3.5     1.4         0.2          0
# 1  4.9  3.0     1.4         0.2          0
# 2  4.7  3.2     1.3         0.2          0
# 3  4.6  3.1     1.5         0.2          0
# 4  5.0  3.6     1.4         0.2          0

# %% [markdown]
# ### Separando Dados

# %%
X = df.iloc[:,:-1]
y = df.iloc[:,-1]

# %% [markdown]
# ### Selecionando os 2 primeiros componentes do PCA

# %%
X_pca = PCA().fit_transform(X)

print(X.shape)

X_selected = X_pca[:,:2]

print(X_selected.shape)
# Out:
# (150, 4)
# (150, 2)

# %% [markdown]
# ### Treinando Classificador SVM

# %%
# Definir variáveis para meshgrid
h = .01
x_min, x_max = -4,4
y_min, y_max = -1.5, 1.5


clf = SVC(kernel='rbf', max_iter=1500)
clf.fit(X_selected, y)
xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                     np.arange(y_min, y_max, h))
Z = clf.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)

# %% [markdown]
# ### Plotando Caracterísitcas em um Plano

# %%
from sklearn.metrics import accuracy_score

cmap_light = ListedColormap(['#FFAAAA', '#AAFFAA', '#AAAAFF'])
cmap_bold = ListedColormap(['#FF0000', '#00FF00', '#0000FF'])
plt.figure(figsize=(10,5))
plt.pcolormesh(xx, yy, Z, alpha=.6,cmap=cmap_light)
plt.title('PCA - Iris dataset')
plt.xlabel('Dimension 1')
plt.ylabel('Dimension 2')
plt.scatter(X_pca[:,0], X_pca[:,1], c=y, cmap=cmap_bold)
plt.show()


preds = clf.predict(X_selected)
acc = accuracy_score(preds, y)
print(f"Acc: {acc*100}%")
# Out:
# Acc: 96.0%

# %% [markdown]
# ### Treinando Classificador MLP

# %%
from sklearn.neural_network import MLPClassifier


clf = MLPClassifier(hidden_layer_sizes=25,
                    activation="logistic",
                    solver='sgd',
                    max_iter=150)
clf.fit(X_selected, y)
xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                     np.arange(y_min, y_max, h))
Z = clf.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)


cmap_light = ListedColormap(['#FFAAAA', '#AAFFAA', '#AAAAFF'])
cmap_bold = ListedColormap(['#FF0000', '#00FF00', '#0000FF'])
plt.figure(figsize=(10,5))
plt.pcolormesh(xx, yy, Z, alpha=.6,cmap=cmap_light)
plt.title('PCA - Iris dataset')
plt.xlabel('Dimension 1')
plt.ylabel('Dimension 2')
plt.scatter(X_pca[:,0], X_pca[:,1], c=y, cmap=cmap_bold)
plt.show()

# %% [markdown]
# ### Treinando Classificador RandomForest

# %%
from sklearn.ensemble import RandomForestClassifier


clf = RandomForestClassifier(n_estimators=50)
clf.fit(X_selected, y)
xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                     np.arange(y_min, y_max, h))
Z = clf.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)


cmap_light = ListedColormap(['#FFAAAA', '#AAFFAA', '#AAAAFF'])
cmap_bold = ListedColormap(['#FF0000', '#00FF00', '#0000FF'])
plt.figure(figsize=(10,5))
plt.pcolormesh(xx, yy, Z, alpha=.6,cmap=cmap_light)
plt.title('PCA - Iris dataset')
plt.xlabel('Dimension 1')
plt.ylabel('Dimension 2')
plt.scatter(X_pca[:,0], X_pca[:,1], c=y, cmap=cmap_bold)
plt.show()


preds = clf.predict(X_selected)
acc = accuracy_score(preds, y)
print(f"Acc: {acc*100}%")
# Out:
# Acc: 100.0%
