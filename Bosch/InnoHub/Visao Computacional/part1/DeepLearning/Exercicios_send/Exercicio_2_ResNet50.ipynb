# %% [markdown]
# # CNN Resnet50
#
# #### Diferencial:
# * Conv Block
# * Identity Block
#
#
# ![image.png](attachment:image.png)
#
#
# B = BatchNormalization <br>
# R = ReLU <br>
# S = SoftMax
#
# Filtros :
# * [64, 64, 256]
# * [128, 128, 512]
# * [256, 256, 102]
# * [512, 512, 2048]

# %%
# Import Layers
from tensorflow.keras.layers import Input, Dense, GlobalAveragePooling2D, Conv2D
from tensorflow.keras.models import Model
from tensorflow.keras.layers import ReLU, Add
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import MaxPooling2D

# %% [markdown]
# ### Identity Block

# %%
def identity_block(x, filters):
    pass

# %% [markdown]
# ### Conv Block
#
# #### Por que skip layers?
#     Ao aumentar a profundidade a rede a performance fica saturada.
#     Pesquisadores da Microsoft resolveram este problema com a ResNet, utilizando
#     skip layers na construção de modelos mais profundos.

# %%
def conv_block(x, filters, strides=(2, 2)):
    pass

# %% [markdown]
# ### ResNet50

# %%
class ResNet50:

    @staticmethod
    def build(inputs=(224, 224, 3), outputs=1000):

        input_ = Input(inputs)        
               
        pass

# %%
class ResNet50:

    @staticmethod
    def build(inputs=(224, 224, 3), outputs=1000):
        pass
