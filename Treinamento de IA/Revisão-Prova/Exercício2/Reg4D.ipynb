# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression,Lasso
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import math

df = pd.read_csv('Advertising.csv', index_col= 0)
df = df.dropna()
df.head(5)
# Out:
#       TV  radio  newspaper  sales
# 1  230.1   37.8       69.2   22.1
# 2   44.5   39.3       45.1   10.4
# 3   17.2   45.9       69.3    9.3
# 4  151.5   41.3       58.5   18.5
# 5  180.8   10.8       58.4   12.9

# %%
X = df[["TV","radio","newspaper"]]
Y = df["sales"]

X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size=0.3, random_state=22)

# %%
#Regressao linear
import matplotlib
from matplotlib.pyplot import plot


regressor = LinearRegression()
regressor.fit(X_train,Y_train)
R2 = regressor.score(X_test,Y_test)
MSE = mean_squared_error(Y_test, regressor.predict(X_test))
RMSE = math.sqrt(mean_squared_error(Y_test, regressor.predict(X_test)))


fig = plt.figure(dpi=100)
ax = fig.add_subplot(111,projection='3d')
ax.scatter(X_test["radio"],Y_test,X_test["TV"],c='red',marker='o',alpha=0.5)
ax.scatter(X_test["radio"],regressor.predict(X_test),X_test["TV"],color='k')
plt.show()

print("MEtricas:")
print(f'R^2:{R2}')
print(f"MSE: {MSE}")
print(f"RMSE: {RMSE}")
# Out:
# MEtricas:
# R^2:0.9048887393988819
# MSE: 2.536563159652865
# RMSE: 1.592659147354783
