# %% [markdown]
# ### Comparação entre modo Sequencial e API do Keras

# %%
# Importart Layers 
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import Input, Dense, Flatten, Reshape, Concatenate
from tensorflow.keras.utils import plot_model

# %%
"""
Definir os tamanhos de Entrada e saída para um exemplo de MNIST
"""

input_shape = (28, 28)
output_shape = 10

# %% [markdown]
# ## Modo Sequencial
#
# * Mais simples
# * Criar layer por layer
# * Mais utilizado para modelos sem muita complexidade

# %% [markdown]
# Modelo gráfico
# <img src="../images/1_x1bZ9rUu9994-07ihFJsQA.jpeg">

# %% [markdown]
# #### Limitações
#
# Apesar de ser mais fácil, quando aplicado a modelos mais complexos não é tão prático utilizar o modo sequencial, Pois com ele não podemos:
#
# * Dividir camadas em braços
# * Ter mais de uma entrada
# * Ter mais de uma saída
#
# Como por exemplo:
#
# * Cumberstone Models
#
# ![image.png](attachment:image.png)
#
#
#
# * AutoEncoders:
#
# ![image-2.png](attachment:image-2.png)
#
#
#
# * Redes siamesas:
#
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# #### Modo API
#
# Permite a construção de modelos mais complexos, nomeação de camas, multiplas entradas/saídas.

# %%
# Out:
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            [(None, 28, 28)]     0
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 784)          0           input_1[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 256)          200960      flatten[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 128)          32896       dense[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 784)          101136      dense_1[0][0]
# ...

# %% [markdown]
# Modelo gráfico
# <img src="../images/1_cR8tQeL9VKDfdAOuNn5aeA.jpeg">
