# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('materiais/Dados/respiradores.csv')
df.head(3)
# Out:
#        MES   ACRE  ALAGOAS  AMAPA  AMAZONAS  BAHIA  CEARA  DISTRITO FEDERAL  \
# 0  2020/04    0.0      0.0   45.0      90.0    0.0   45.0               0.0
# 1  2020/05   30.0     30.0   60.0      88.0   60.0   30.0               0.0
# 2  2020/06  120.0    105.0   20.0      44.0  246.0  105.0             200.0
#
#    ESPIRITO SANTO   GOIAS  ...  RIO DE JANEIRO  RIO GRANDE DO NORTE  \
# 0             10.0    0.0  ...              60                  0.0
# 1             60.0   25.0  ...             577                 80.0
# 2             85.0  251.0  ...             177                 97.0
#
#    RIO GRANDE DO SUL   RONDONIA  RORAIMA  SANTA CATARINA  SERGIPE  SÃO PAULO  \
# 0                 0.0       0.0      0.0            17.0      0.0        0.0
# 1                 0.0      65.0     75.0             0.0     70.0      460.0
# 2               297.0     126.0     50.0            56.0     60.0      296.0
#
#    TOCANTINS  TOTAL
# 0        0.0    387
# 1       20.0   2284
# ...

# %%
x = df.MES
altura = df.TOTAL
plt.bar(x,altura,1.5,align= "center", edgecolor="black")
plt.title("COMPRA DE RESPIRADORES POR MÊS")
plt.xticks(rotation = '90')
plt.yticks(rotation = '45')
plt.show()

# %%
total_por_estado = df.sum()[1:-1]

# %%
x = df.columns[1:-1] # PULO MES E SELECIPNO TODAS AS COLUNAS
plt.bar(x,total_por_estado, color="black",zorder =3)
plt.title("COMPRA DE RESPIRADORES POR ESTADO")
plt.xticks(rotation = "vertical")
plt.grid(zorder = 0)
plt.show()

# %%
plt.plot(df.MES,df.PARANA,marker='o', label = 'Paraná')
plt.plot(df.MES,df['SÃO PAULO'],marker='o', label = 'São Paulo')
plt.plot(df.MES,df['SANTA CATARINA'],marker='o', label = 'Santa Catarina')
plt.legend()
plt.xticks(rotation='45')
plt.grid(linestyle='dashed')
plt.show()

# %% [markdown]
# # Desafio Modao

# %%
print(df.iloc[1:5,7:25])
# Out:
#    DISTRITO FEDERAL  ESPIRITO SANTO   GOIAS  HAITI   LIBANO  MARANHÃO  \
# 1               0.0             60.0   25.0     0.0     0.0      45.0
# 2             200.0             85.0  251.0     0.0     0.0     196.0
# 3              50.0             79.0  296.0     0.0     0.0      49.0
# 4               0.0             37.0  108.0     0.0   300.0      19.0
#
#    MATO GROSSO   MATO GROSSO DO SUL  MINAS GERAIS  PARA  PARAIBA  PARANA  \
# 1           0.0                 0.0           0.0   284    130.0     0.0
# 2         150.0               100.0         389.0    42    115.0   254.0
# 3          90.0               119.0         339.0    21     87.0   291.0
# 4          14.0                62.0         182.0    23     12.0    73.0
#
#    PERNAMBUCO  PERU  PIAUI  RIO DE JANEIRO  RIO GRANDE DO NORTE  \
# 1        75.0   0.0   20.0             577                 80.0
# 2        40.0   0.0   70.0             177                 97.0
# ...

# %%
norte=df.loc[:, ["MES","AMAZONAS", "AMAPA", "RORAIMA", "ACRE", "PARA", "RONDONIA", "TOCANTINS"]]
sul=df.loc[:, ["MES","PARANA", "RIO GRANDE DO SUL ", "SANTA CATARINA"]]
sudeste = df.loc[:, ["MES","MINAS GERAIS", "ESPIRITO SANTO ", "RIO DE JANEIRO", "SÃO PAULO"]]
centro = df.loc[: ,["MES","GOIAS","MATO GROSSO ", "MATO GROSSO DO SUL", "DISTRITO FEDERAL"]]
nordeste = df.loc[:,["MES","MARANHÃO","PIAUI","RIO GRANDE DO NORTE","CEARA","PARAIBA","BAHIA","PERNAMBUCO","ALAGOAS","SERGIPE"]]
#insert total of buy in df

# %%
def soma(linha,regiao):
    counter = 0
    for i in regiao.columns:
        counter+= linha[i]
    return counter

print(sul)

def count_total_buy(data):
    total_array = []
    for rows in data.row:
        counter = 0
        for column in data.columns:
            counter += rows[column]
        total_array.append(counter)
    return total_array

print(count_total_buy(sul.iloc[:,1:-1]))

# totaldeCompraNorte = df.apply(soma,axis=1,regiao=norte)
# total_de_compra_sul = df.apply(soma,axis=1,regiao=sul)
# total_de_compra_nordeste = df.apply(soma,axis=1, regiao=nordeste)
# total_de_compras_centro = df.apply(soma,axis=1, regiao=centro)
# total_de_compra_sudeste = df.apply(soma,axis=1, regiao=sudeste)
# total_de_compra_nordeste.sum()
# Out:
#         MES  PARANA  RIO GRANDE DO SUL   SANTA CATARINA
# 0   2020/04    20.0                 0.0            17.0
# 1   2020/05     0.0                 0.0             0.0
# 2   2020/06   254.0               297.0            56.0
# 3   2020/07   291.0               362.0            65.0
# 4   2020/08    73.0                92.0             5.0
# 5   2020/09    39.0               108.0             0.0
# 6   2020/10    47.0                49.0             1.0
# 7   2020/11   134.0                32.0             2.0
# 8   2020/12   118.0                73.0           117.0
# 9   2021/01     3.0                15.0             0.0
# 10  2021/02    14.0                 0.0           100.0
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-133-137ef0c465bd> in <module>
#      16     return total_array
#      17
# ---> 18 print(count_total_buy(sul.iloc[:,1:-1]))
# ...
