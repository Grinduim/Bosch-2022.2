# %% [markdown]
# # LeNet vs ANN for KMNIST

# %%
from tensorflow.keras.layers import Dense, Conv2D
from tensorflow.keras.layers import ReLU
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.layers import Softmax
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten

from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import SparseCategoricalCrossentropy
from tensorflow.keras.metrics import SparseCategoricalAccuracy

# %% [markdown]
# ### Set some configutation

# %%
inputs = (28, 28, 1)
outputs = 10      
epochs = 10
optimizer = Adam(0.001)

# %% [markdown]
# ### Load Data
#
# Kuzushiji-MNIST is a drop-in replacement for the MNIST dataset (28x28 grayscale, 70,000 images), provided in the original MNIST format as well as a NumPy format. Since MNIST restricts us to 10 classes, we chose one character to represent each of the 10 rows of Hiragana when creating Kuzushiji-MNIST

# %%
import numpy as np


train_x = np.load("dataset/kmnist-train-imgs.npz")
train_x = train_x.f.arr_0
train_y = np.load("dataset/kmnist-train-labels.npz")
train_y = train_y.f.arr_0
test_x = np.load("dataset/kmnist-test-imgs.npz")
test_x = test_x.f.arr_0
test_y = np.load("dataset/kmnist-test-labels.npz")
test_y = test_y.f.arr_0



print(f"Dataset Treino com {len(train_x)} Amostras e {len(set(train_y))} Classes")
print(f"Dataset Teste com {len(test_x)} Amostras e {len(set(test_y))} Classes")
# Out:
# Dataset Treino com 60000 Amostras e 10 Classes
# Dataset Teste com 10000 Amostras e 10 Classes

# %% [markdown]
# ### Visualize data

# %% [markdown]
# ### Prepare data

# %% [markdown]
# # LeNet
#
# Input = (28, 28)<br>
# Outputs = 10<br>
# Filtros = 16, 64<br>
#
#
# ![image-2.png](attachment:image-2.png)
#
#
# #### Perguntas:
#
# * Hidden = ?
# * Sequential  ou API?

# %% [markdown]
# # ANN
#
# Input = (28, 28)<br>
# Outputs = 10<br>
#
# #### Perguntas:
# * Hidden = ?

# %% [markdown]
# ### Compile models

# %% [markdown]
# ### Train Models

# %% [markdown]
# ### Validate Models
